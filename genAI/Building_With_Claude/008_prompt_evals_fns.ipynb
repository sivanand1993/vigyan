# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\nimport sys\n\ndef parse_s3_bucket_name(uri):\n    match = re.match(r'^s3://([a-zA-Z0-9._-]+)(?:/|$)', uri)\n    if match:\n        return match.group(1)\n    return None\n\nif __name__ == \"__main__\":\n    # Test cases\n    test_uris = [\n        \"s3://my-bucket-name/path/to/object\",\n        \"s3://bucket-123/file.txt\",\n        \"s3://my.bucket/\",\n        \"s3://bucket\",\n        \"invalid-uri\"\n    ]\n    \n    for uri in test_uris:\n        result = parse_s3_bucket_name(uri)\n        print(json.dumps({\"uri\": uri, \"bucket\": result}))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket-name/path/to/object')",
#       "format": "regex"
#     },
#     "score": 3.0,
#     "reasoning": "The solution correctly solves the core parsing task and handles basic edge cases, but the regex pattern diverges from actual AWS S3 bucket naming conventions. While the pattern will work for most real-world bucket names (since they typically follow AWS rules), it would incorrectly accept invalid bucket names like 's3://MyBucket_123/' which violate AWS policies. The solution lacks comprehensive validation and could benefit from better error reporting."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda IAM execution role with basic S3 read permissions\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ],\n        \"Policies\": [\n          {\n            \"PolicyName\": \"S3ReadPolicy\",\n            \"PolicyDocument\": {\n              \"Version\": \"2012-10-17\",\n              \"Statement\": [\n                {\n                  \"Effect\": \"Allow\",\n                  \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:ListBucket\"\n                  ],\n                  \"Resource\": [\n                    \"arn:aws:s3:::*\",\n                    \"arn:aws:s3:::*/*\"\n                  ]\n                }\n              ]\n            }\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template for an AWS Lambda IAM execution role with basic S3 read permissions",
#       "format": "json"
#     },
#     "score": 8.0,
#     "reasoning": "The template is syntactically correct and follows AWS best practices for the overall structure. However, it has a significant security flaw by granting S3 read access to all buckets via wildcards, violating the principle of least privilege. This is a production-ready template structure but with overly permissive permissions that should be scoped to specific S3 resources."
#   },
#   {
#     "output": "\nimport boto3\nfrom typing import Dict, Any\n\ndef get_instance_metadata(instance_id: str) -> Dict[str, Any]:\n    \"\"\"\n    Takes an AWS EC2 instance ID and returns a formatted dictionary with instance metadata.\n    \n    Args:\n        instance_id: The EC2 instance ID (e.g., 'i-0123456789abcdef0')\n    \n    Returns:\n        A formatted dictionary containing instance metadata\n    \"\"\"\n    ec2_client = boto3.client('ec2')\n    \n    response = ec2_client.describe_instances(InstanceIds=[instance_id])\n    \n    instance = response['Reservations'][0]['Instances'][0]\n    \n    tags = {tag['Key']: tag['Value'] for tag in instance.get('Tags', [])}\n    \n    security_groups = [sg['GroupId'] for sg in instance.get('SecurityGroups', [])]\n    \n    network_interfaces = []\n    for ni in instance.get('NetworkInterfaces', []):\n        network_interfaces.append({\n            'NetworkInterfaceId': ni['NetworkInterfaceId'],\n            'PrivateIpAddress': ni['PrivateIpAddress'],\n            'PublicIpAddress': ni.get('Association', {}).get('PublicIp'),\n            'SubnetId': ni['SubnetId']\n        })\n    \n    metadata = {\n        'InstanceId': instance['InstanceId'],\n        'InstanceType': instance['InstanceType'],\n        'State': instance['State']['Name'],\n        'LaunchTime': instance['LaunchTime'].isoformat(),\n        'AvailabilityZone': instance['Placement']['AvailabilityZone'],\n        'VpcId': instance.get('VpcId'),\n        'SubnetId': instance.get('SubnetId'),\n        'PrivateIpAddress': instance.get('PrivateIpAddress'),\n        'PublicIpAddress': instance.get('PublicIpAddress'),\n        'PublicDnsName': instance.get('PublicDnsName'),\n        'PrivateDnsName': instance.get('PrivateDnsName'),\n        'KeyName': instance.get('KeyName'),\n        'SecurityGroups': security_groups,\n        'NetworkInterfaces': network_interfaces,\n        'RootDeviceName': instance.get('RootDeviceName'),\n        'RootDeviceType': instance.get('RootDeviceType'),\n        'EbsOptimized': instance.get('EbsOptimized', False),\n        'Monitoring': instance.get('Monitoring', {}).get('State'),\n        'Tags': tags,\n        'Architecture': instance.get('Architecture'),\n        'VirtualizationType': instance.get('VirtualizationType'),\n        'IamInstanceProfile': instance.get('IamInstanceProfile', {}).get('Arn')\n    }\n    \n    return metadata\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID and returns a formatted dictionary with instance metadata extracted from a boto3 describe_instances response",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly fulfills the core requirement and demonstrates good coding practices with type hints, documentation, and defensive dictionary access. However, it has a critical gap in error handling - it will crash ungracefully when given an invalid instance ID, which is a common real-world scenario. Adding try-except blocks and validating the response structure would significantly improve production-readiness. The datetime serialization choice is reasonable for JSON compatibility but should be documented."
#   }
# ]
