# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()

model="claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text
    })

# %%
messages = []
add_user_message(messages, "Write a one sentence description of a fake database.")

stream=client.messages.create(
    model=model,
    messages=messages,
    stream=True,
    max_tokens=1000
)

for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_01VmH4xWybRZLFCVooPYgPjJ', container=None, content=[], model='claude-sonnet-4-20250514', role='assistant', stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=1, server_tool_use=None, service_tier='standard')), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='The', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' "GlobalPet Registry" is a fictional database containing detailed profiles', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' of over 50 million household pets worldwide, including their breeds, medical histories, behavioral traits, and owner', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' contact information.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=17, output_tokens=42, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
messages = []
add_user_message(messages, "Write a one sentence description of a fake database.")

with client.messages.stream(
    model=model,
    messages=messages,
    max_tokens=1000
) as stream:    
    for text in stream.text_stream:
        print(text,end="" )
# Out:
# The Global Pet Emotion Database contains over 2.3 million entries documenting the daily mood fluctuations of household pets as interpreted by their owners through a standardized 47-point emotional spectrum scale.

# %%
stream.get_final_message()
# Out:
# ParsedMessage(id='msg_01E9GgKebxJHF4sGbNZ9MH5x', container=None, content=[ParsedTextBlock(citations=None, text='The Global Pet Emotion Database contains over 2.3 million entries documenting the daily mood fluctuations of household pets as interpreted by their owners through a standardized 47-point emotional spectrum scale.', type='text', parsed_output=None)], model='claude-sonnet-4-20250514', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=46, server_tool_use=None, service_tier='standard'))
