# %%
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.86.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from anthropic)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.14 (from anthropic)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.86.0-py3-none-any.whl (469 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl (205 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 27.9 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, python-dotenv, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, anthropic
#
#    -- -------------------------------------  1/17 [sniffio]
#    ---- -----------------------------------  2/17 [python-dotenv]
#    ---- -----------------------------------  2/17 [python-dotenv]
#    ---- -----------------------------------  2/17 [python-dotenv]
#    --------- ------------------------------  4/17 [idna]
#    --------- ------------------------------  4/17 [idna]
#    --------- ------------------------------  4/17 [idna]
#    ----------- ----------------------------  5/17 [h11]
#    ----------- ----------------------------  5/17 [h11]
#    ----------- ----------------------------  5/17 [h11]
#    ----------- ----------------------------  5/17 [h11]
#    -------------- -------------------------  6/17 [docstring-parser]
#    -------------- -------------------------  6/17 [docstring-parser]
#    -------------- -------------------------  6/17 [docstring-parser]
#    -------------- -------------------------  6/17 [docstring-parser]
#    -------------- -------------------------  6/17 [docstring-parser]
#    ---------------- -----------------------  7/17 [distro]
#    ---------------- -----------------------  7/17 [distro]
#    ------------------ ---------------------  8/17 [certifi]
#    ----------------------- ---------------- 10/17 [typing-inspection]
#    ------------------------- -------------- 11/17 [pydantic-core]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ---------------------------------------- 17/17 [anthropic]
#
# Successfully installed annotated-types-0.7.0 anthropic-0.86.0 anyio-4.12.1 certifi-2026.2.25 distro-1.9.0 docstring-parser-0.17.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.13.0 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.2 sniffio-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()

model="claude-sonnet-4-0"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
message.content[0].text
# Out:
# 'Quantum computing is a revolutionary computing paradigm that uses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain problems exponentially faster than classical computers.'

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text
    })

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

add_assistant_message(messages, final_answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

add_assistant_message(messages, final_answer)

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a revolutionary computing paradigm that harnesses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain problems exponentially faster than classical computers.'},
#  {'role': 'user', 'content': 'Write another sentence'},
#  {'role': 'assistant',
#   'content': 'Unlike classical computers that use bits representing either 0 or 1, quantum computers use quantum bits (qubits) that can exist in multiple states simultaneously, enabling them to perform many calculations in parallel.'},
#  {'role': 'user', 'content': 'Write another sentence'},
#  {'role': 'assistant',
#   'content': 'However, quantum computers are extremely fragile and require near absolute zero temperatures and isolation from environmental interference to maintain their quantum states, making them currently suitable only for specialized applications rather than general-purpose computing.'}]
